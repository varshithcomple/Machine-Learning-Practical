# %%
#varaibles and types
x=5
y=3.14
name="CGPA"
is_placed=True
print(x, type(x))
print(y,type(y))
print(name, type(name))
print(is_placed, type(is_placed))
# Out:
# 5 <class 'int'>
# 3.14 <class 'float'>
# CGPA <class 'str'>
# True <class 'bool'>

# %%
#ARITHMETIC OPERATIONS
a=7
b=2
print("a+b=",a+b)
print("a-b=",a-b)
print("a*b=",a*b)
print("a/b=",a/b)
print("a ** 2 ", a** 2)
# Out:
# a+b= 9
# a-b= 5
# a*b= 14
# a/b= 3.5
# a ** 2  49

# %%
#COMPARISON OPERATIONS
cgpa=9.2
print("cgpa == 9.2 : ", cgpa==9.2)
print("cgpa >9 : ",cgpa>9)
print("cgpa<6 :", cgpa<6)
# Out:
# cgpa == 9.2 :  True
# cgpa >9 :  True
# cgpa<6 : False
